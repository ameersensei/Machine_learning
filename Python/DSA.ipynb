# %% [markdown]
# # DSA of python

# %% [markdown]
# --- Data structure in python

# %% [markdown]
# --Types of Data structure

# %% [markdown]
# ![ClassificationofDataStructure.png](attachment:ClassificationofDataStructure.png)

# %% [markdown]
# source - https://www.geeksforgeeks.org/the-ultimate-beginners-guide-for-dsa/
